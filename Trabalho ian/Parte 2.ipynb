# %% [markdown]
# Parte 2:
# Nesta segunda parte do trabalho temos um conjunto de pontos e vamos utilizar o metodo dos minimos quadrados (MMQ) para aproximar da melhor forma possivel o conjunto de pontos dado.
# Começamos por importar e fazer o plot dos pontos e depois utilizamos o MMQ para criar a melhor aproximação possivel.

# %% [markdown]
# Exemplo 1:

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

x_vals = []
y_vals = []

with open('g14data_9b7ddc558100e309f290a85682ba320e.csv', 'r', newline='') as arquivo_csv:
    leitor_csv = csv.reader(arquivo_csv)
    next(leitor_csv) 
    for linha in leitor_csv:
        x_vals.append(float(linha[0]))
        y_vals.append(float(linha[1]))
     

plt.figure(figsize=(8, 6))
plt.plot(x_vals, y_vals, 'ro', markersize=3)  
plt.title('Gráfico de y')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
x = np.array(x_vals)
y = np.array(y_vals)

FB = [lambda x: x, lambda x: np.sin(x), lambda x: np.cos(x)]

dim = len(FB)
A = np.zeros((dim,dim))
B = np.zeros(dim)

for i in range(dim):
    B[i]= np.inner(FB[i](x),y)
    for j in range(dim):
        A[i,j] = np.inner(FB[i](x),FB[j](x))
        
print('Matriz A:\n', A)
print('Matriz B:\n',B)
a = np.linalg.solve(A,B)
print('Matriz dos coeficientes:\n',a)
def g (x):
    gg=0
    for i in range(dim):
        gg+=a[i]*FB[i](x)
    return gg

erro = 0
for i in range (len(x_vals)):
    erro += (g(x)[i]-y_vals[i])**2
    
print('Erro total:\n',erro)

plt.figure(figsize=(8, 6))
plt.plot(x, y, 'ro', markersize=3)
plt.plot(x,g(x))
plt.grid(True)
plt.show()
# Out:
# Matriz A:
#  [[ 5.48134163e+04 -2.02180595e+02  3.25824157e+01]
#  [-2.02180595e+02  1.26253319e+02 -3.10063202e+00]
#  [ 3.25824157e+01 -3.10063202e+00  1.23746681e+02]]
# Matriz B:
#  [-22128.52212109    206.16200986    113.27858136]
# Matriz dos coeficientes:
#  [-0.40057654  1.01714235  1.04636436]
# Erro total:
#  21.86416113481939

# %% [markdown]
# Usamos no Fb as funções: x, sen(x) e cos(x). Podendo usar qualquer outra não garantido resultados tão bons mas proporciona uma generalização maior do código usado.
# O erro obtido é de aproximandamente 21,864 o que é o melhor possivel tendo em conta os pontos e usando esta função de ajustamento.

# %% [markdown]
# Exemplo 2:

# %%
x_vals = []
y_vals = []

with open('dados2.csv', 'r', newline='') as arquivo_csv:
    leitor_csv = csv.reader(arquivo_csv)
    next(leitor_csv) 
    for linha in leitor_csv:
        x_vals.append(float(linha[0]))
        y_vals.append(float(linha[1]))
     

plt.figure(figsize=(8, 6))
plt.plot(x_vals, y_vals, 'ro', markersize=3)  
plt.title('Gráfico de y')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
x = np.array(x_vals)
y = np.array(y_vals)

FB = [lambda x: x, lambda x: x**2, lambda x: x**3]

dim = len(FB)
A = np.zeros((dim,dim))
B = np.zeros(dim)

for i in range(dim):
    B[i]= np.inner(FB[i](x),y)
    for j in range(dim):
        A[i,j] = np.inner(FB[i](x),FB[j](x))
        
print('Matriz A:\n', A)
print('Matriz B:\n',B)
a = np.linalg.solve(A,B)
print('Matriz dos coeficientes:\n',a)
def g (x):
    gg=0
    for i in range(dim):
        gg+=a[i]*FB[i](x)
    return gg

erro = 0
for i in range (len(x_vals)):
    erro += (g(x)[i]-y_vals[i])**2
    
print('Erro total:\n',erro)

plt.figure(figsize=(8, 6))
plt.plot(x, y, 'ro', markersize=3)
plt.plot(x,g(x))
plt.grid(True)
plt.show()
# Out:
# Matriz A:
#  [[  638.97796787  1452.69225942  3541.2362855 ]
#  [ 1452.69225942  3541.2362855   9026.97657153]
#  [ 3541.2362855   9026.97657153 23737.87415255]]
# Matriz B:
#  [1348.19682838 3112.08447012 7659.42778038]
# Matriz dos coeficientes:
#  [ 1.51521101  0.35678097 -0.03904924]
# Erro total:
#  28.92769423661848

# %% [markdown]
# Usamos no Fb as funções: x, x^2 e x^3.
# O erro obtido é de aproximandamente 28,928 o que é o melhor possivel tendo em conta os pontos e usando esta função de ajustamento.
